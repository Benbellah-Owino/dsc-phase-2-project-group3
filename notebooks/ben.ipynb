# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
imd_conn = sqlite3.connect("./data/im.db")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-42a971fdabb0> in <module>
# ----> 1 imd_conn = sqlite3.connect("./data/im.db")
#
# OperationalError: unable to open database file
