# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
# !ls ./data
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
imd_conn = sqlite3.connect("../data/im.db")
